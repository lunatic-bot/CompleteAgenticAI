# %% [markdown]
# ## Model integration with openAI, Google Gemini, and groq

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ['GROQ_API_KEY']=os.getenv('GROQ_API_KEY')
os.environ['GEMINI_API_KEY']=os.getenv('GEMINI_API_KEY')

# %%
from langchain.chat_models import init_chat_model

# %%
model = init_chat_model("google_genai:gemini-3.6-flash")

# %%
## invoke the model
response=model.invoke("Hellow, how are you?")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': "Hello! I'm doing great, thank you for asking. How are you doing today? \n\nHow can I help you with something?", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0664c-a166-7611-8e13-fc124dcc30b1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 347, 'total_tokens': 355, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 318}})

# %%
##second Method
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-3.6-flash")
response=model.invoke("Hellow, how are you?")
print(response)
# Out:
# content=[{'type': 'text', 'text': "Hello! I'm doing well, thank you for asking. How are you doing today? How can I help you?", 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a0664f-50ea-73b1-bac3-52db64cb83ea-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 145, 'total_tokens': 153, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 120}}

# %% [markdown]
# ### Groq Model integration

# %%
import os
from langchain.chat_models import init_chat_model
# model = init_chat_model("groq:qwen/qwen3.6-27b")
model = init_chat_model("groq:openai/gpt-oss-120b")
response=model.invoke("Hellow, how are you?")
print(response)
# Out:
# content="Hello! I'm doing great, thank you for asking. How can I assist you today?" additional_kwargs={'reasoning_content': 'The user says "Hellow, how are you?" It\'s a simple greeting. We respond politely.'} response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 78, 'total_tokens': 126, 'completion_time': 0.099493657, 'completion_tokens_details': {'reasoning_tokens': 21}, 'prompt_time': 0.003540275, 'prompt_tokens_details': None, 'queue_time': 0.363094561, 'total_time': 0.103033932}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_e1a78f200e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a06657-a168-7371-999a-abc8cb7d6d0d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 78, 'output_tokens': 48, 'total_tokens': 126, 'output_token_details': {'reasoning': 21}}

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="openai/gpt-oss-120b")
response=model.invoke("Hellow, Why earth is round?")
response
# Out:
# AIMessage(content='Hello! Great question—\u200bthe reason Earth (and most large celestial bodies) is round comes down to gravity and the way matter behaves when it’s massive enough.\n\n### 1. Gravity pulls everything toward the center\n- **Gravity** is a force that attracts all mass toward the center of mass.  \n- On a small object, like a mountain or a building, the material is strong enough to hold a non‑round shape because gravity is relatively weak compared with the material’s structural strength.\n\n### 2. When an object gets big enough, it becomes “fluid” under its own weight\n- As a body grows larger (think of a planet‑size object), the gravitational pressure inside becomes enormous.  \n- At those pressures, even solid rock behaves like a very slow‑moving fluid; it can flow, albeit over millions of years.\n\n### 3. Hydrostatic equilibrium → a sphere\n- A fluid (or a material that can flow) under its own gravity will settle into the shape that **minimizes potential energy**—that is, the shape where every point on the surface is as close as possible to the center.  \n- That shape is a sphere (or, more precisely, an **oblate spheroid** because Earth rotates, making it slightly flattened at the poles and bulged at the equator).\n\n### 4. The role of rotation\n- Earth spins once every ~24\u202fhours. The centrifugal effect from this rotation pushes material outward at the equator, giving Earth a tiny equatorial bulge.  \n- The resulting shape is called an **oblate spheroid**: still essentially round, just a bit squashed.\n\n### 5. Evidence we see\n- **Photographs from space** clearly show Earth’s round silhouette.  \n- **Satellite orbits** work only if Earth’s gravity behaves as if it comes from a roughly spherical mass.  \n- **Travel and navigation** (airlines, ships) rely on great‑circle routes, which are the shortest paths on a sphere.\n\n### TL;DR\nEarth is round because its own gravity pulls matter toward a common center. When an object is massive enough, the material can’t stay in a jagged shape; it flows (over geological timescales) into the shape that balances the forces—\u200ba sphere. Earth’s rotation makes it a slightly squashed sphere, but to everyday eyes it’s “round.”\n\nHope that clears it up! Feel free to ask if you’d like more detail about any part of the process.', additional_kwargs={'reasoning_content': 'The user asks "Hellow, Why earth is round?" They want an explanation. It\'s a simple question. Provide answer: gravity, hydrostatic equilibrium, formation, etc. Should be friendly. No policy issues.'}, response_metadata={'token_usage': {'completion_tokens': 566, 'prompt_tokens': 79, 'total_tokens': 645, 'completion_time': 1.179822749, 'completion_tokens_details': {'reasoning_tokens': 44}, 'prompt_time': 0.029523033, 'prompt_tokens_details': None, 'queue_time': 0.281475638, 'total_time': 1.209345782}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_df9620fe21', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a06659-1c4f-75f1-9f83-47202038ce4c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 79, 'output_tokens': 566, 'total_tokens': 645, 'output_token_details': {'reasoning': 44}})
